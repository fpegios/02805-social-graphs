# %% [markdown]
# # Formalia:
#
# Please read the [assignment overview page](https://github.com/suneman/socialgraphs2018/wiki/Assignments) carefully before proceeding. This page contains information about formatting (including formats etc), group sizes, and many other aspects of handing in the assignment.
#
# _If you fail to follow these simple instructions, it will negatively impact your grade!_
#
# **Due date and time**: The assignment is due on Tuesday November 6th at 23:55. Hand in your IPython notebook file (with extension `.ipynb`) via http://peergrade.io/.

# %% [markdown]
# # Part 1: Twitter Network Analysis
#
# _Exercise_ 1: Build the network of retweets.
# We will now build a network that has as nodes the Twitter handles of the members of the house, and direct edges between nodes A and B if A has retweeted content posted by B. We will build a weighted network, where the weight of an edge is equal to the number of retweets. You can build the network following the steps below (and you should  be able to reuse many of the functions you wrote in previous weeks):
#
# * Consider the 200 most recent tweets written by each member of the house (use the files [here](https://github.com/suneman/socialgraphs2018/tree/master/files/data_twitter/tweets.zip), or the ones you produced in Part 1). For each file, use a regular expression to find retweets and to extract the Twitter handle of the user whose content was retweeted. All retweets begin with "_RT @originalAuthor:_", where "_originalAuthor_" is the handle of the user whose content was retweeted (and the part of the text you want to extract).
# * For each retweet, check if the handle retweeted is the one of a member of the house. If yes, keep it. If no, discard it.
# * Use a NetworkX [`DiGraph`](https://networkx.github.io/documentation/development/reference/classes.digraph.html) to store the network. Use weighted edges to account for multiple retweets. Store also the party of each member as a node attribute (use the data in [this file](https://github.com/suneman/socialgraphs2018/blob/master/files/data_twitter/H115_tw.csv), or the data you downloaded in Part 1). Remove self-loops (edges that connect a node with itself).

# %%
# Exercise 1

import re
import io #read file
import os
import csv

# array that holds the name of the house members
house_members = [];

for filename in os.listdir("tweets/"):
    # store name of house member
    house_members.append(filename);


# save parties with handles
with open('parties.csv', 'rb') as csvfile:
    # Skip first line (if any)
    next(csvfile, None)
    parties = [];
    party_handles = [];
    
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in spamreader:
        row_content = row[0].split(',')
        parties.append(row_content[0]);
        party_handles.append(row_content[1]);
        
# array of members
members = [];

# create class for members
class Member():
    handle = "";
    party = "";
    retweet_handles = [];
    
    def __init__(self, handle, party, retweet_handles):
        self.handle = handle;
        self.party = party;
        self.retweet_handles = retweet_handles;

# find all files in folder
for filename in os.listdir("tweets/"):    
    # open file
    filepath = "tweets/" + filename
    file = io.open(filepath, 'r', encoding='utf-8');
    
    handles = [];
    # search for retweet
    for line in file: 
        if re.match(r'^RT', line):
            line_in_array = line.split(); # put words in array cells
            handle = line_in_array[1]; # second cell contains the handle with @ and :
            handle_clean = handle.replace("@", "").replace(":", ""); # remove @ and : from handle
            if not handle_clean in handles: # avoid duplicates
                if handle_clean in house_members: # discared handles that do not exist in house members
                    handles.append(handle_clean);
    
    
    # find member party
    for index, member in enumerate(party_handles, start=0):   # default is zero
        if filename == party_handles[index]:
            handle_party = "";
            handle_party = parties[index];
            break;
    
    members.append(Member(filename, handle_party, handles));
    
for member in members:
    print "Member handle: ", member.handle
    print "Member party: ", member.party
    print "Retweet handles: ", member.retweet_handles
    print "\n"
# Out:
# Member handle:  AustinScottGA08
# Member party:  Republican
# Retweet handles:  [u'AustinScottGA08']
#
#
# Member handle:  BennieGThompson
# Member party:  Democratic
# Retweet handles:  [u'RepCummings', u'RepJeffries', u'RepDebDingell', u'RepJohnYarmuth', u'RepBonnie', u'RepCheri', u'RepVeasey', u'FrankPallone', u'RepBarbaraLee', u'RepRaskin', u'BobbyScott', u'RepStephMurphy', u'RepGwenMoore', u'RepDanKildee', u'RepDennyHeck', u'RepJerryNadler', u'GKButterfield', u'RepAnnieKuster', u'RepKarenBass', u'RepBeatty', u'RepJuanVargas', u'WhipHoyer', u'RepWilson', u'NancyPelosi', u'RepJayapal', u'RepEspaillat', u'RepTedLieu', u'RepTimWalz', u'RepKClark', u'RepMarciaFudge', u'RepMcEachin', u'RepAlGreen', u'RepRichmond', u'RepEsty']
#
#
# Member handle:  BettyMcCollum04
# Member party:  Democratic
# Retweet handles:  [u'RepBeatty', u'RepCummings', u'RepJeffries', u'RepDebDingell', u'RepJohnYarmuth', u'repmarkpocan', u'RepRaulGrijalva', u'RepRichardNeal', u'USRepMikeDoyle', u'FrankPallone', u'RepDelBene']
#
#
# Member handle:  BillPascrell
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  BobbyScott
# Member party:  Democratic
# Retweet handles:  [u'RepBeatty', u'RepCummings', u'repmarkpocan', u'USRepMikeDoyle', u'RepAdams', u'RepKarenBass', u'RepTerriSewell', u'RepMcEachin', u'FrankPallone', u'NancyPelosi', u'RepStephMurphy', u'WhipHoyer', u'RepAnthonyBrown']
#
#
# Member handle:  boblatta
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  BradSherman
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  Call_Me_Dutch
# Member party:  Democratic
# Retweet handles:  [u'RepCummings', u'RepAnthonyBrown', u'BettyMcCollum04', u'RepRaskin', u'janschakowsky', u'RepStephMurphy', u'RepJerryNadler']
#
#
# Member handle:  cathymcmorris
# Member party:  Republican
# Retweet handles:  [u'SteveScalise']
#
#
# Member handle:  chelliepingree
# Member party:  Democratic
# Retweet handles:  [u'RepDavidYoung', u'janschakowsky']
#
#
# Member handle:  Clyburn
# Member party:  Democratic
# Retweet handles:  [u'RepTerriSewell', u'NancyPelosi', u'BobbyScott', u'RepMcEachin', u'repjoecrowley', u'RepRichmond', u'Clyburn', u'RepCuellar']
#
#
# Member handle:  ConawayTX11
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'RepMarthaRoby', u'RepDavidRouzer', u'RepRickCrawford', u'RodneyDavis', u'AustinScottGA08', u'RepLaMalfa', u'cathymcmorris', u'RepBost', u'SteveScalise', u'RepKinzinger', u'RepMikeRogersAL', u'RepRickAllen', u'ConawayTX11', u'RepHensarling', u'HurdOnTheHill']
#
#
# Member handle:  congbillposey
# Member party:  Republican
# Retweet handles:  [u'congbillposey', u'RosLehtinen', u'MarshaBlackburn']
#
#
# Member handle:  CongCulberson
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'SpeakerRyan', u'RepKevinBrady', u'RepGeneGreen', u'cathymcmorris']
#
#
# Member handle:  CongMikeSimpson
# Member party:  Republican
# Retweet handles:  [u'HurdOnTheHill', u'SpeakerRyan']
#
#
# Member handle:  CongPalazzo
# Member party:  Republican
# Retweet handles:  [u'GOPLeader']
#
#
# Member handle:  CongressmanGT
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'RepDerekKilmer', u'JimLangevin', u'RepTomMarino', u'SpeakerRyan', u'CongressmanRaja']
#
#
# Member handle:  CongressmanHice
# Member party:  Republican
# Retweet handles:  [u'RepLeeZeldin', u'RepMarkMeadows']
#
#
# Member handle:  CongressmanRaja
# Member party:  Democratic
# Retweet handles:  [u'CongressmanRaja', u'RepCummings', u'RepLaHood', u'repjohnlewis', u'DonaldNorcross', u'RepBobbyRush', u'RepDonBeyer', u'RepSchneider']
#
#
# Member handle:  CongressmanRuiz
# Member party:  Democratic
# Retweet handles:  [u'RepJohnYarmuth', u'RepLouCorrea', u'RepDianaDeGette']
#
#
# Member handle:  DarrellIssa
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  daveloebsack
# Member party:  Democratic
# Retweet handles:  [u'boblatta', u'RepRyanCostello']
#
#
# Member handle:  davereichert
# Member party:  Republican
# Retweet handles:  [u'RepKevinBrady']
#
#
# Member handle:  davidcicilline
# Member party:  Democratic
# Retweet handles:  [u'RepJoeKennedy', u'RepSarbanes', u'JimLangevin', u'davidcicilline', u'BillPascrell']
#
#
# Member handle:  DesJarlaisTN04
# Member party:  Republican
# Retweet handles:  [u'PeterRoskam', u'CongMikeSimpson', u'RepJeffDuncan', u'SteveScalise', u'RepAndyBarr', u'rep_stevewomack', u'boblatta', u'RepSeanDuffy', u'RepRWilliams', u'virginiafoxx', u'RepMikeBishop', u'RepBuddyCarter', u'RepJeffDenham', u'RepBradWenstrup', u'RepLeeZeldin', u'Robert_Aderholt', u'RepMikeRogersAL', u'RepGosar', u'GOPLeader', u'RepRobWoodall', u'MarshaBlackburn', u'RepJimBanks', u'DarrellIssa', u'RepMimiWalters', u'RepBillFlores', u'RepFrenchHill', u'PatrickMcHenry']
#
#
# Member handle:  DonaldNorcross
# Member party:  Democratic
# Retweet handles:  [u'RepBonnie', u'janschakowsky', u'RepDebDingell', u'repmarkpocan', u'RepAdamSchiff']
#
#
# Member handle:  DorisMatsui
# Member party:  Democratic
# Retweet handles:  [u'janschakowsky', u'RepLoisFrankel', u'RepMarcyKaptur', u'RepMcEachin', u'NancyPelosi', u'BobbyScott', u'RepAdamSchiff', u'RepLBR', u'RepBeatty', u'USRepKCastor', u'RepAnnieKuster', u'RepJohnYarmuth', u'RepValDemings']
#
#
# Member handle:  DrNealDunnFL2
# Member party:  Republican
# Retweet handles:  [u'RepKayGranger', u'SteveScalise']
#
#
# Member handle:  DrPhilRoe
# Member party:  Republican
# Retweet handles:  [u'RepAnnWagner', u'SpeakerRyan', u'RepJimRenacci']
#
#
# Member handle:  DWStweets
# Member party:  Democratic
# Retweet handles:  [u'repjohnlewis']
#
#
# Member handle:  farenthold
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan']
#
#
# Member handle:  FrankPallone
# Member party:  Democratic
# Retweet handles:  [u'RepBeatty', u'RepJohnYarmuth', u'repmarkpocan', u'RepHankJohnson', u'RepKarenBass', u'RepBonnie', u'RepAnnieKuster']
#
#
# Member handle:  GerryConnolly
# Member party:  Democratic
# Retweet handles:  [u'RepDonBeyer', u'WhipHoyer', u'RepScottPeters']
#
#
# Member handle:  GKButterfield
# Member party:  Democratic
# Retweet handles:  [u'repjohnlewis', u'RepDwightEvans', u'WhipHoyer', u'GKButterfield', u'RepDavidEPrice']
#
#
# Member handle:  GOPLeader
# Member party:  Republican
# Retweet handles:  [u'RepLouBarletta', u'RepLaMalfa', u'RepKevinBrady', u'RepBost', u'RepMimiWalters', u'repgregwalden', u'RepJeffDenham', u'RepStefanik', u'RepKristiNoem', u'RepMikeBishop', u'RepKHandel', u'RepJasonLewis', u'RepAndyBarr', u'RepTenney', u'SteveKnight25', u'RodneyDavis', u'RepDonBacon', u'RepComstock', u'RepBrianMast', u'RepMikeCoffman']
#
#
# Member handle:  gracenapolitano
# Member party:  Democratic
# Retweet handles:  [u'RepJeffries', u'JoaquinCastrotx', u'RepJohnYarmuth', u'RepHankJohnson', u'CongressmanRuiz', u'RepSarbanes', u'RepJayapal', u'NancyPelosi', u'RepRaulGrijalva', u'rosadelauro', u'RepSwalwell', u'RepVeasey', u'FrankPallone', u'RepRoybalAllard', u'RepCheri', u'RepStephMurphy', u'RepJudyChu', u'BobbyScott', u'RepGwenMoore', u'RepDanKildee', u'RepAdamSchiff', u'RepRubenGallego', u'RepDebDingell', u'RepJerryNadler', u'RepAnthonyBrown', u'RepJuanVargas', u'RepCummings', u'RepValDemings', u'WhipHoyer', u'RepJimmyGomez', u'RepJohnKatko']
#
#
# Member handle:  GreggHarper
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'RepByrne', u'cathymcmorris']
#
#
# Member handle:  HerreraBeutler
# Member party:  Republican
# Retweet handles:  [u'cathymcmorris']
#
#
# Member handle:  HurdOnTheHill
# Member party:  Republican
# Retweet handles:  [u'CongMikeSimpson']
#
#
# Member handle:  JacksonLeeTX18
# Member party:  Democratic
# Retweet handles:  [u'repjohnlewis', u'NancyPelosi', u'RepHankJohnson', u'RepKClark', u'RepAdamSchiff']
#
#
# Member handle:  jahimes
# Member party:  Democratic
# Retweet handles:  [u'BillPascrell', u'justinamash', u'RepMikeCoffman']
#
#
# Member handle:  janschakowsky
# Member party:  Democratic
# Retweet handles:  [u'RepDonBeyer', u'RepBeatty', u'RepMikeQuigley', u'RepJeffries', u'RepJoeKennedy', u'JoaquinCastrotx', u'RepDianaDeGette', u'RepBrady', u'RepRaulGrijalva', u'repmarkpocan', u'USRepMikeDoyle', u'RepSarbanes', u'JacksonLeeTX18', u'chelliepingree', u'RepRobinKelly', u'RepLoisFrankel', u'RepLawrence', u'RepAnnieKuster', u'NancyPelosi', u'RepBobbyRush', u'RepJayapal', u'RepMarcyKaptur', u'RepRichardNeal', u'RepLloydDoggett', u'WhipHoyer']
#
#
# Member handle:  JeffFortenberry
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan']
#
#
# Member handle:  JimLangevin
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  JimPressOffice
# Member party:  Republican
# Retweet handles:  [u'RepSeanDuffy', u'RepAnnieKuster', u'SpeakerRyan', u'PeterWelch', u'RepGrothman']
#
#
# Member handle:  Jim_Jordan
# Member party:  Republican
# Retweet handles:  [u'RepMarkMeadows', u'WarrenDavidson', u'RepGosar', u'RepGoodlatte', u'CongressmanHice', u'RepLeeZeldin', u'RepAndyBiggsAZ']
#
#
# Member handle:  JoaquinCastrotx
# Member party:  Democratic
# Retweet handles:  [u'JoaquinCastrotx', u'RepGregoryMeeks', u'RepEBJ', u'sethmoulton', u'RepJimmyGomez', u'RepAdamSchiff', u'RepRubenGallego', u'RepJoeKennedy', u'WhipHoyer']
#
#
# Member handle:  JudgeCarter
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'PeteSessions']
#
#
# Member handle:  JudgeTedPoe
# Member party:  Republican
# Retweet handles:  [u'NormaJTorres', u'SteveScalise', u'RepTomGarrett', u'cathymcmorris']
#
#
# Member handle:  JuliaBrownley26
# Member party:  Democratic
# Retweet handles:  [u'RepAnnieKuster']
#
#
# Member handle:  justinamash
# Member party:  Republican
# Retweet handles:  [u'RepThomasMassie', u'justinamash']
#
#
# Member handle:  keithellison
# Member party:  Democratic
# Retweet handles:  [u'keithellison', u'RepJayapal']
#
#
# Member handle:  KenCalvert
# Member party:  Republican
# Retweet handles:  [u'RepHolding', u'SpeakerRyan', u'cathymcmorris', u'SusanWBrooks', u'RepMimiWalters']
#
#
# Member handle:  KYComer
# Member party:  Republican
# Retweet handles:  [u'RepGoodlatte']
#
#
# Member handle:  LacyClayMO1
# Member party:  Democratic
# Retweet handles:  [u'RepMarciaFudge', u'RepAdamSchiff', u'repjohnlewis', u'repcleaver', u'RepJoeKennedy', u'NancyPelosi', u'RepSwalwell', u'RepMaxineWaters']
#
#
# Member handle:  LamarSmithTX21
# Member party:  Republican
# Retweet handles:  [u'TXRandy14', u'SpeakerRyan']
#
#
# Member handle:  louiseslaughter
# Member party:  Democratic
# Retweet handles:  [u'RepMaloney']
#
#
# Member handle:  MacTXPress
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'RobWittman', u'RepChuck', u'RepDonBacon', u'GOPLeader', u'cathymcmorris', u'RepGallagher']
#
#
# Member handle:  MarkAmodeiNV2
# Member party:  Republican
# Retweet handles:  [u'SteveScalise']
#
#
# Member handle:  MarshaBlackburn
# Member party:  Republican
# Retweet handles:  [u'SteveScalise']
#
#
# Member handle:  michaelcburgess
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  MikeKellyPA
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'cathymcmorris']
#
#
# Member handle:  NancyPelosi
# Member party:  Democratic
# Retweet handles:  [u'RepBeatty', u'RepGwenMoore', u'RepCummings', u'RepJeffries', u'JoaquinCastrotx', u'RepDebDingell', u'RepBrady', u'RepJohnYarmuth', u'repmarkpocan', u'RepHankJohnson', u'CongressmanRuiz', u'RepKarenBass', u'RepSarbanes', u'RepRoybalAllard', u'RepTerriSewell', u'RepAnnieKuster', u'JacksonLeeTX18', u'JimLangevin', u'RepRaulGrijalva', u'RepLloydDoggett', u'RepRichardNeal', u'USRepMikeDoyle', u'FrankPallone', u'RepAnnaEshoo']
#
#
# Member handle:  nikiinthehouse
# Member party:  Democratic
# Retweet handles:  [u'RepLawrence', u'RepSpeier', u'USRepKCastor', u'RepKClark']
#
#
# Member handle:  NitaLowey
# Member party:  Democratic
# Retweet handles:  [u'RepMikeQuigley', u'RepBarbaraLee', u'RepEliotEngel', u'WhipHoyer', u'BettyMcCollum04', u'chelliepingree']
#
#
# Member handle:  NormaJTorres
# Member party:  Democratic
# Retweet handles:  [u'RepRoybalAllard']
#
#
# Member handle:  PatrickMcHenry
# Member party:  Republican
# Retweet handles:  [u'RepDavidEPrice', u'RepRichHudson', u'SpeakerRyan', u'RepHolding', u'SteveScalise', u'GOPLeader']
#
#
# Member handle:  PatTiberi
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'RepCurbelo', u'RepSteveStivers', u'GOPLeader', u'RepKevinBrady', u'SpeakerRyan']
#
#
# Member handle:  PeterRoskam
# Member party:  Republican
# Retweet handles:  [u'RepKevinBrady', u'cathymcmorris', u'RodneyDavis', u'RepDianeBlack', u'RepLaHood']
#
#
# Member handle:  PeterWelch
# Member party:  Democratic
# Retweet handles:  [u'chelliepingree']
#
#
# Member handle:  PeteSessions
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  Raul_Labrador
# Member party:  Republican
# Retweet handles:  [u'RepMcSally']
#
#
# Member handle:  RepAbraham
# Member party:  Republican
# Retweet handles:  [u'LamarSmithTX21']
#
#
# Member handle:  RepAdams
# Member party:  Democratic
# Retweet handles:  [u'JacksonLeeTX18', u'NancyPelosi', u'RepAnthonyBrown', u'RepGwenMoore']
#
#
# Member handle:  RepAdamSchiff
# Member party:  Democratic
# Retweet handles:  [u'RepJoeKennedy']
#
#
# Member handle:  RepAdamSmith
# Member party:  Democratic
# Retweet handles:  [u'RepCummings', u'RepDebDingell', u'RepJayapal', u'repmarkpocan', u'RepRoKhanna', u'RepRaulGrijalva', u'RepTedLieu']
#
#
# Member handle:  RepAdrianSmith
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepAlexMooney
# Member party:  Republican
# Retweet handles:  [u'RepDaveBrat', u'SteveScalise']
#
#
# Member handle:  RepAlGreen
# Member party:  Democratic
# Retweet handles:  [u'RepAlGreen']
#
#
# Member handle:  RepAlLawsonJr
# Member party:  Democratic
# Retweet handles:  [u'RepAdams', u'GKButterfield', u'NancyPelosi', u'RepWilson', u'CongressmanRaja']
#
#
# Member handle:  RepAndreCarson
# Member party:  Democratic
# Retweet handles:  [u'RepHankJohnson', u'RepDanKildee', u'RepStephMurphy', u'WhipHoyer']
#
#
# Member handle:  RepAndyBarr
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'SteveScalise', u'RepBlaine']
#
#
# Member handle:  RepAndyBiggsAZ
# Member party:  Republican
# Retweet handles:  [u'SteveScalise']
#
#
# Member handle:  RepAndyHarrisMD
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'RepJohnDelaney', u'SpeakerRyan', u'GOPLeader']
#
#
# Member handle:  RepAnnaEshoo
# Member party:  Democratic
# Retweet handles:  [u'RepMcGovern', u'RepMcEachin', u'USRepMikeDoyle', u'RepErikPaulsen', u'RepDebDingell', u'RepDianaDeGette', u'RepAnnaEshoo', u'RepLowenthal', u'RepThompson', u'RepDeSaulnier', u'RepJayapal', u'NancyPelosi', u'SusanWBrooks', u'RepSpeier', u'rosadelauro', u'RepJuanVargas', u'RepCardenas', u'RepValDemings', u'DorisMatsui', u'RepMcNerney']
#
#
# Member handle:  RepAnnieKuster
# Member party:  Democratic
# Retweet handles:  [u'RepJoeKennedy', u'RepSarbanes', u'RepRaulGrijalva', u'RepLoisFrankel', u'RepCheri']
#
#
# Member handle:  RepAnnWagner
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'RepDaveBrat', u'RepMarthaRoby', u'cathymcmorris', u'RosLehtinen', u'SteveScalise']
#
#
# Member handle:  RepAnthonyBrown
# Member party:  Democratic
# Retweet handles:  [u'RepDonBeyer', u'RepCummings', u'RepMaxineWaters', u'RepJohnYarmuth', u'Call_Me_Dutch', u'RepAnthonyBrown', u'RepRaulGrijalva', u'RepBarbaraLee', u'GerryConnolly', u'NancyPelosi']
#
#
# Member handle:  RepArrington
# Member party:  Republican
# Retweet handles:  [u'RepBrianFitz']
#
#
# Member handle:  RepBarbaraLee
# Member party:  Democratic
# Retweet handles:  [u'CongressmanRaja', u'GKButterfield', u'RepMarkTakano', u'chelliepingree', u'RepJerryNadler', u'RepJoeKennedy', u'RepAdamSmith', u'RepDebDingell', u'RepMcNerney', u'BettyMcCollum04', u'USRepKCastor', u'RepRaulGrijalva', u'repmarkpocan', u'RepEliotEngel', u'RepDonBeyer', u'RepAnnaEshoo', u'RepLowenthal', u'RepMaloney', u'RepJayapal', u'RepCharlieCrist', u'repdinatitus', u'RepLBR', u'RepGraceMeng', u'janschakowsky', u'RepLoisFrankel', u'DorisMatsui', u'RepLawrence', u'RepSpeier']
#
#
# Member handle:  RepBarragan
# Member party:  Democratic
# Retweet handles:  [u'RepDonBeyer', u'repjohnlewis', u'RepRoybalAllard', u'RepCharlieCrist', u'RepKarenBass', u'RepSarbanes']
#
#
# Member handle:  RepBeatty
# Member party:  Democratic
# Retweet handles:  [u'RepRoybalAllard', u'RepGwenMoore', u'RepRobinKelly', u'repmarkpocan', u'RepJerryNadler', u'RepWilson', u'CongressmanRuiz', u'RepSteveStivers', u'RepAnnieKuster', u'RepSpeier', u'USRepMikeDoyle', u'RepCummings']
#
#
# Member handle:  RepBera
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepBetoORourke
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepBillFlores
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'SteveScalise', u'cathymcmorris']
#
#
# Member handle:  RepBillFoster
# Member party:  Democratic
# Retweet handles:  [u'RepEliotEngel', u'RepJerryNadler']
#
#
# Member handle:  RepBillJohnson
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'RepTimRyan']
#
#
# Member handle:  RepBillShuster
# Member party:  Republican
# Retweet handles:  [u'RepSamGraves', u'SpeakerRyan', u'SteveScalise', u'RepSmucker', u'RepLouBarletta', u'GOPLeader']
#
#
# Member handle:  RepBlaine
# Member party:  Republican
# Retweet handles:  [u'RepTomGraves', u'SpeakerRyan']
#
#
# Member handle:  repblumenauer
# Member party:  Democratic
# Retweet handles:  [u'RepJoeKennedy', u'repjohnlewis', u'repdinatitus']
#
#
# Member handle:  RepBobbyRush
# Member party:  Democratic
# Retweet handles:  [u'RepLloydDoggett', u'RepSchneider', u'janschakowsky']
#
#
# Member handle:  RepBobGibbs
# Member party:  Republican
# Retweet handles:  [u'GOPLeader', u'SpeakerRyan', u'RepTomGraves', u'SteveScalise', u'RepJeffDenham', u'RepRickAllen', u'RepMcKinley']
#
#
# Member handle:  RepBonamici
# Member party:  Democratic
# Retweet handles:  [u'RepSchrader', u'RepJohnYarmuth', u'RepLoisFrankel', u'RepBarragan', u'WhipHoyer', u'RepJayapal', u'RepAnnieKuster', u'JacksonLeeTX18', u'RepRaulGrijalva', u'RepBonamici']
#
#
# Member handle:  RepBonnie
# Member party:  Democratic
# Retweet handles:  [u'GerryConnolly', u'RepBeatty', u'USRepMikeDoyle', u'RepLawrence', u'RepDianaDeGette', u'RepBarragan', u'RepBarbaraLee', u'RepDonBeyer', u'RepBonnie', u'repcleaver', u'RepDwightEvans', u'RepVeasey', u'RepMarkTakano', u'FrankPallone']
#
#
# Member handle:  RepBost
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'RodneyDavis']
#
#
# Member handle:  RepBradWenstrup
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'SpeakerRyan', u'RepTomGraves']
#
#
# Member handle:  RepBrady
# Member party:  Democratic
# Retweet handles:  [u'NancyPelosi', u'RepTedDeutch', u'RepMcGovern', u'BillPascrell', u'RepBetoORourke']
#
#
# Member handle:  RepBrendanBoyle
# Member party:  Democratic
# Retweet handles:  [u'RepDanKildee']
#
#
# Member handle:  RepBrianBabin
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepBrianFitz
# Member party:  Republican
# Retweet handles:  [u'RepSinema', u'RepMarkMeadows', u'RepAndyBiggsAZ', u'RepHuffman', u'RepStephMurphy']
#
#
# Member handle:  RepBrianHiggins
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepBrianMast
# Member party:  Republican
# Retweet handles:  [u'RepCurbelo', u'RepStephMurphy']
#
#
# Member handle:  RepBuddyCarter
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'RepEliotEngel', u'SteveScalise', u'cathymcmorris']
#
#
# Member handle:  RepByrne
# Member party:  Republican
# Retweet handles:  [u'RepGosar', u'RepMarthaRoby', u'RepAdams', u'SteveScalise']
#
#
# Member handle:  RepCarbajal
# Member party:  Democratic
# Retweet handles:  [u'RepSwalwell']
#
#
# Member handle:  RepCardenas
# Member party:  Democratic
# Retweet handles:  [u'RepBonnie', u'NormaJTorres', u'WhipHoyer', u'CongressmanRuiz', u'RepJerryNadler', u'RepJudyChu', u'RepMikeQuigley', u'RepAnthonyBrown', u'RepPaulTonko', u'RepDonBeyer', u'RepRaulGrijalva', u'NitaLowey', u'NancyPelosi']
#
#
# Member handle:  RepCartwright
# Member party:  Democratic
# Retweet handles:  [u'RepRoKhanna', u'RosLehtinen', u'RepTedLieu', u'janschakowsky', u'RepVeasey', u'PeterRoskam', u'RepLawrence']
#
#
# Member handle:  RepCharlieCrist
# Member party:  Democratic
# Retweet handles:  [u'RepMarcyKaptur', u'RepMcNerney', u'RepDavidEPrice', u'RepBarragan', u'RepEBJ', u'RepRaulGrijalva', u'DonaldNorcross', u'RepGwenMoore', u'RepCarbajal', u'RepHastingsFL', u'RepBonamici']
#
#
# Member handle:  RepCheri
# Member party:  Democratic
# Retweet handles:  [u'RepBeatty', u'RepTerriSewell', u'RepJeffries', u'RepDebDingell', u'RepJohnYarmuth', u'daveloebsack', u'RepSarbanes', u'RepSpeier', u'davidcicilline', u'RepAnnieKuster', u'FrankPallone', u'RepVeasey', u'RepMaloney', u'RepPerlmutter', u'RepDianaDeGette']
#
#
# Member handle:  RepChrisCollins
# Member party:  Republican
# Retweet handles:  [u'PeteSessions', u'SpeakerRyan', u'SteveScalise', u'RepChrisCollins', u'RepTenney']
#
#
# Member handle:  RepChrisSmith
# Member party:  Republican
# Retweet handles:  [u'SteveScalise']
#
#
# Member handle:  RepChrisStewart
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'RepAnthonyBrown', u'RepTomGraves', u'RepSeanDuffy']
#
#
# Member handle:  RepChuck
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'SpeakerRyan']
#
#
# Member handle:  RepClayHiggins
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'GOPLeader', u'CongPalazzo', u'JimPressOffice']
#
#
# Member handle:  repcleaver
# Member party:  Democratic
# Retweet handles:  [u'repcleaver']
#
#
# Member handle:  RepCohen
# Member party:  Democratic
# Retweet handles:  [u'NancyPelosi', u'RepCohen', u'RepKinzinger']
#
#
# Member handle:  RepComstock
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan']
#
#
# Member handle:  RepConorLamb
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepCuellar
# Member party:  Democratic
# Retweet handles:  [u'RepCuellar']
#
#
# Member handle:  RepCummings
# Member party:  Democratic
# Retweet handles:  [u'Call_Me_Dutch', u'WhipHoyer', u'repjohnlewis', u'RepLloydDoggett', u'GerryConnolly', u'RepAdams', u'RepAnthonyBrown']
#
#
# Member handle:  RepCurbelo
# Member party:  Republican
# Retweet handles:  [u'RosLehtinen', u'RepBrianFitz', u'SteveScalise', u'RepJoshG', u'RepJoeWilson', u'RepPeteOlson']
#
#
# Member handle:  RepDanDonovan
# Member party:  Republican
# Retweet handles:  [u'SusanWBrooks', u'NitaLowey', u'RepPeteKing', u'RepStefanik', u'SteveScalise', u'RepAnnieKuster']
#
#
# Member handle:  RepDanKildee
# Member party:  Democratic
# Retweet handles:  [u'RepJeffries', u'RepStephMurphy']
#
#
# Member handle:  RepDannyDavis
# Member party:  Democratic
# Retweet handles:  [u'RepJohnLarson', u'RepRichardNeal', u'RepLloydDoggett', u'RepBobbyRush', u'RepGwenMoore']
#
#
# Member handle:  RepDarrenSoto
# Member party:  Democratic
# Retweet handles:  [u'RepJohnYarmuth', u'RepJimmyGomez', u'RepLloydDoggett', u'JoaquinCastrotx', u'RepDonBeyer', u'RepVeasey', u'RepValDemings', u'RepDarrenSoto', u'RepStephMurphy']
#
#
# Member handle:  RepDaveBrat
# Member party:  Republican
# Retweet handles:  [u'RepAnnWagner', u'RepKevinBrady', u'SteveScalise']
#
#
# Member handle:  RepDaveJoyce
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'RepDaveJoyce', u'SpeakerRyan', u'RepSteveStivers']
#
#
# Member handle:  RepDaveTrott
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'SteveScalise', u'RepCurbelo', u'GOPLeader', u'RepWalberg', u'FrankPallone', u'RepKristiNoem', u'RepDebDingell', u'RepMikeBishop']
#
#
# Member handle:  RepDavid
# Member party:  Republican
# Retweet handles:  [u'RepMcSally', u'RepMarkWalker', u'RepBillJohnson', u'replouiegohmert', u'RepKevinBrady', u'TGowdySC', u'RepWalorski']
#
#
# Member handle:  RepDavidEPrice
# Member party:  Democratic
# Retweet handles:  [u'RepAdamSchiff', u'RepMikeQuigley', u'RepSarbanes', u'RepAdams', u'RepSchneider', u'NancyPelosi']
#
#
# Member handle:  RepDavidKustoff
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'cathymcmorris', u'RepChuck']
#
#
# Member handle:  RepDavidRouzer
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'SpeakerRyan']
#
#
# Member handle:  repdavidscott
# Member party:  Democratic
# Retweet handles:  [u'RepHankJohnson', u'BobbyScott', u'RepLawrence']
#
#
# Member handle:  RepDavidValadao
# Member party:  Republican
# Retweet handles:  [u'RepSeanDuffy', u'RepJimmyPanetta']
#
#
# Member handle:  RepDavidYoung
# Member party:  Republican
# Retweet handles:  [u'chelliepingree', u'RepStefanik']
#
#
# Member handle:  RepDebDingell
# Member party:  Democratic
# Retweet handles:  [u'RepMcGovern', u'RepPaulMitchell', u'RepWalberg', u'JacksonLeeTX18', u'RepJayapal', u'RepAdams', u'RepSpeier', u'RepRaulGrijalva', u'RepHankJohnson', u'RepFredUpton']
#
#
# Member handle:  RepDelBene
# Member party:  Democratic
# Retweet handles:  [u'RepBonamici', u'RepTerriSewell']
#
#
# Member handle:  RepDennisRoss
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'RepMikeRogersAL', u'cathymcmorris', u'RepTomGraves', u'RepDennisRoss']
#
#
# Member handle:  RepDennyHeck
# Member party:  Democratic
# Retweet handles:  [u'RepCummings', u'RepDerekKilmer', u'RepVeasey', u'FrankPallone', u'RepCheri', u'BobbyScott', u'RepDanKildee']
#
#
# Member handle:  RepDerekKilmer
# Member party:  Democratic
# Retweet handles:  [u'WhipHoyer', u'davereichert']
#
#
# Member handle:  RepDeSantis
# Member party:  Republican
# Retweet handles:  [u'RosLehtinen', u'RepLeeZeldin', u'Jim_Jordan', u'RepMarkMeadows', u'RepRodBlum']
#
#
# Member handle:  RepDeSaulnier
# Member party:  Democratic
# Retweet handles:  [u'RepDebDingell', u'repmarkpocan', u'RepAnnieKuster', u'RepJerryNadler', u'RepJoeKennedy', u'RepRichardNeal', u'DonaldNorcross', u'RepAdamSchiff']
#
#
# Member handle:  RepDevinNunes
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepDianaDeGette
# Member party:  Democratic
# Retweet handles:  [u'RepBeatty', u'NancyPelosi', u'RepDebDingell', u'RepJohnYarmuth', u'repmarkpocan', u'RepKarenBass', u'RepAnnieKuster', u'WhipHoyer', u'USRepMikeDoyle', u'FrankPallone']
#
#
# Member handle:  RepDianeBlack
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'RepMattGaetz', u'RepOHalleran']
#
#
# Member handle:  repdinatitus
# Member party:  Democratic
# Retweet handles:  [u'GerryConnolly']
#
#
# Member handle:  RepDLamborn
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'GOPLeader', u'RepNewhouse', u'cathymcmorris']
#
#
# Member handle:  RepDonBacon
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan']
#
#
# Member handle:  RepDonBeyer
# Member party:  Democratic
# Retweet handles:  [u'RepDonBeyer', u'janschakowsky', u'RepBeatty', u'GKButterfield', u'USRepMikeDoyle', u'RepRaskin', u'RepTedDeutch', u'WhipHoyer', u'NancyPelosi', u'RepGwenMoore', u'RepJohnLarson', u'RepCummings', u'RepJeffries', u'JoaquinCastrotx', u'RepDianaDeGette', u'RepJohnYarmuth', u'repmarkpocan', u'RepMarciaFudge', u'RepHankJohnson', u'RepEBJ']
#
#
# Member handle:  repdonyoung
# Member party:  Republican
# Retweet handles:  [u'RepBonamici', u'cathymcmorris', u'SpeakerRyan']
#
#
# Member handle:  RepDougCollins
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'RepJudyChu']
#
#
# Member handle:  RepDrewFerguson
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepDwightEvans
# Member party:  Democratic
# Retweet handles:  [u'RepDwightEvans', u'USRepMikeDoyle', u'repjohnlewis', u'RepBarbaraLee']
#
#
# Member handle:  RepEBJ
# Member party:  Democratic
# Retweet handles:  [u'RepEliotEngel', u'WhipHoyer', u'RepBarbaraLee']
#
#
# Member handle:  RepEdRoyce
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'SpeakerRyan', u'RepBeatty', u'RosLehtinen', u'RepKevinBrady', u'RepEdRoyce']
#
#
# Member handle:  RepEliotEngel
# Member party:  Democratic
# Retweet handles:  [u'repjohnlewis', u'FrankPallone', u'repmarkpocan', u'RepDonBeyer', u'RepBarbaraLee', u'RepTedLieu', u'RepRaulGrijalva', u'RepEliotEngel', u'davidcicilline', u'RepCummings', u'RepJayapal', u'NancyPelosi', u'RepAdamSchiff']
#
#
# Member handle:  RepErikPaulsen
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'RepKevinBrady', u'SpeakerRyan', u'RepChuck', u'RepCurbelo', u'cathymcmorris', u'RepLouBarletta', u'RepAnnWagner']
#
#
# Member handle:  RepEspaillat
# Member party:  Democratic
# Retweet handles:  [u'RepEspaillat', u'repmarkpocan']
#
#
# Member handle:  RepEsty
# Member party:  Democratic
# Retweet handles:  [u'RepJohnLarson', u'rosadelauro', u'repjohnlewis']
#
#
# Member handle:  RepFrankLucas
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepFredUpton
# Member party:  Republican
# Retweet handles:  [u'RepDebDingell']
#
#
# Member handle:  RepFrenchHill
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepGallagher
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan']
#
#
# Member handle:  RepGaramendi
# Member party:  Democratic
# Retweet handles:  [u'RepThompson', u'RepTedLieu']
#
#
# Member handle:  RepGarretGraves
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepGeneGreen
# Member party:  Democratic
# Retweet handles:  [u'JoaquinCastrotx', u'WhipHoyer', u'RepDebDingell', u'RepJohnYarmuth', u'USRepMikeDoyle', u'RepLloydDoggett', u'RepDianaDeGette', u'RepRichardNeal', u'RepGeneGreen', u'FrankPallone', u'repjohnlewis', u'RepCheri']
#
#
# Member handle:  RepGoodlatte
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan']
#
#
# Member handle:  RepGosar
# Member party:  Republican
# Retweet handles:  [u'RepBillJohnson', u'RepTomEmmer', u'RepAndyBiggsAZ']
#
#
# Member handle:  RepGraceMeng
# Member party:  Democratic
# Retweet handles:  [u'RepSwalwell', u'RepSeanMaloney']
#
#
# Member handle:  RepGregoryMeeks
# Member party:  Democratic
# Retweet handles:  [u'NancyPelosi', u'USRepMikeDoyle', u'RepSwalwell', u'RepVeasey', u'RepAdamSchiff']
#
#
# Member handle:  repgregwalden
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepGrothman
# Member party:  Republican
# Retweet handles:  [u'RepWilson']
#
#
# Member handle:  RepGusBilirakis
# Member party:  Republican
# Retweet handles:  [u'RepWebster']
#
#
# Member handle:  RepGuthrie
# Member party:  Republican
# Retweet handles:  [u'RepBonamici', u'RepPeteAguilar', u'RepAndyBarr', u'RepFredUpton', u'RepSmucker', u'GreggHarper', u'SteveScalise']
#
#
# Member handle:  RepGwenMoore
# Member party:  Democratic
# Retweet handles:  [u'RepCummings', u'RepJeffries', u'RepDebDingell', u'RepBrady', u'RepLoisFrankel', u'RepRoKhanna', u'RepBeatty', u'RepKarenBass', u'rosadelauro', u'RepTerriSewell', u'RepAnnieKuster', u'NancyPelosi', u'JacksonLeeTX18', u'RepRaulGrijalva', u'RepLBR', u'RepDennyHeck', u'RepMcGovern', u'RepRichardNeal', u'RepVeasey', u'RepWilson', u'RepCheri']
#
#
# Member handle:  RepHalRogers
# Member party:  Republican
# Retweet handles:  [u'RepKClark', u'SpeakerRyan']
#
#
# Member handle:  RepHanabusa
# Member party:  Democratic
# Retweet handles:  [u'NancyPelosi', u'RepCummings', u'JoaquinCastrotx', u'RepJudyChu', u'JacksonLeeTX18', u'RepLujanGrisham', u'RepLloydDoggett', u'WhipHoyer', u'TulsiPress']
#
#
# Member handle:  RepHankJohnson
# Member party:  Democratic
# Retweet handles:  [u'RepJayapal', u'RepJerryNadler', u'RepBeatty', u'RepMaxineWaters', u'RepCummings', u'RepKarenBass', u'RepBarbaraLee', u'repjohnlewis']
#
#
# Member handle:  RepHartzler
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepHastingsFL
# Member party:  Democratic
# Retweet handles:  [u'GerryConnolly', u'RepBeatty', u'RepCummings', u'RepJeffries', u'RepDebDingell', u'RepBrady', u'RepJohnYarmuth', u'repmarkpocan', u'RepRoKhanna', u'USRepMikeDoyle', u'RepAdams', u'RepTerriSewell', u'FrankPallone', u'RepStephMurphy', u'RepGwenMoore', u'RepMcGovern', u'RepDennyHeck', u'RepAdamSchiff', u'RepJerryNadler', u'RepAnthonyBrown', u'WhipHoyer', u'RepValDemings']
#
#
# Member handle:  RepHensarling
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan']
#
#
# Member handle:  RepHolding
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'RepHolding', u'RepRichHudson', u'PatrickMcHenry', u'RepKevinBrady', u'SpeakerRyan']
#
#
# Member handle:  RepHuffman
# Member party:  Democratic
# Retweet handles:  [u'WhipHoyer', u'NancyPelosi', u'RepDeSaulnier', u'RepWesterman', u'RepAdamSchiff', u'RepBarragan']
#
#
# Member handle:  RepHuizenga
# Member party:  Republican
# Retweet handles:  [u'RepFrenchHill', u'SteveScalise', u'SpeakerRyan', u'GOPLeader', u'RepAndyBarr']
#
#
# Member handle:  RepHultgren
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepJackBergman
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'SpeakerRyan', u'RepHuizenga', u'RepMikeJohnson', u'RepMoolenaar', u'cathymcmorris']
#
#
# Member handle:  RepJackyRosen
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepJaredPolis
# Member party:  Democratic
# Retweet handles:  [u'RepYvetteClarke', u'RepAdams', u'RepMaloney', u'RepEspaillat']
#
#
# Member handle:  RepJasonLewis
# Member party:  Republican
# Retweet handles:  [u'SteveScalise']
#
#
# Member handle:  RepJasonSmith
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepJayapal
# Member party:  Democratic
# Retweet handles:  [u'RepDonBeyer', u'RepJerryNadler', u'RepCummings', u'RepRoKhanna', u'repmarkpocan', u'RepJeffries', u'JoaquinCastrotx', u'RepRaulGrijalva', u'RepLloydDoggett', u'RepRoybalAllard', u'RepSpeier', u'RepBarragan', u'RepAdamSmith']
#
#
# Member handle:  RepJBridenstine
# Member party:  Republican
# Retweet handles:  [u'LamarSmithTX21', u'RepThomasMassie', u'RepDLamborn', u'RepBrianBabin', u'justinamash', u'RepWebster', u'RepJeffDuncan', u'TXRandy14']
#
#
# Member handle:  RepJeffDenham
# Member party:  Republican
# Retweet handles:  [u'SteveKnight25', u'RepSeanDuffy']
#
#
# Member handle:  RepJeffDuncan
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'RepAndyBiggsAZ', u'GOPLeader', u'RepTomRice']
#
#
# Member handle:  RepJeffries
# Member party:  Democratic
# Retweet handles:  [u'RepBeatty', u'RepGwenMoore', u'repmarkpocan', u'NancyPelosi']
#
#
# Member handle:  RepJerryNadler
# Member party:  Democratic
# Retweet handles:  [u'NancyPelosi', u'RepJerryNadler', u'RepSwalwell', u'RepJeffries', u'repjohnlewis', u'RepJoeKennedy', u'janschakowsky', u'RepMaloney', u'RepAdamSchiff', u'RepSchneider', u'RepMcGovern', u'RepRaskin']
#
#
# Member handle:  RepJimBanks
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  repjimcooper
# Member party:  Democratic
# Retweet handles:  [u'repjimcooper']
#
#
# Member handle:  RepJimCosta
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepJimmyGomez
# Member party:  Democratic
# Retweet handles:  [u'RepCummings', u'RepJeffries', u'JoaquinCastrotx', u'RepDianaDeGette', u'RepDebDingell', u'RepBrady', u'RepJohnYarmuth', u'repmarkpocan', u'RepHankJohnson', u'RepKarenBass', u'RepSarbanes', u'RepAnnieKuster', u'RepValDemings', u'JacksonLeeTX18', u'RepRaulGrijalva', u'RepRichardNeal', u'USRepMikeDoyle', u'RepLloydDoggett']
#
#
# Member handle:  RepJimmyPanetta
# Member party:  Democratic
# Retweet handles:  [u'RepGraceMeng', u'RepAnnaEshoo']
#
#
# Member handle:  RepJimRenacci
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepJoeBarton
# Member party:  Republican
# Retweet handles:  [u'RepCuellar', u'SteveScalise', u'SpeakerRyan', u'GOPLeader', u'RepJeffDuncan', u'USRepMikeDoyle', u'RepKevinBrady', u'RepShimkus', u'michaelcburgess']
#
#
# Member handle:  RepJoeCourtney
# Member party:  Democratic
# Retweet handles:  [u'USRepMikeDoyle']
#
#
# Member handle:  repjoecrowley
# Member party:  Democratic
# Retweet handles:  [u'repmarkpocan', u'RepAnnieKuster', u'repjohnlewis', u'RepJimmyGomez']
#
#
# Member handle:  RepJoeKennedy
# Member party:  Democratic
# Retweet handles:  [u'repjohnlewis', u'RepDanKildee', u'WhipHoyer', u'nikiinthehouse', u'sethmoulton']
#
#
# Member handle:  RepJoeWilson
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'SteveScalise']
#
#
# Member handle:  RepJohnConyers
# Member party:  Democratic
# Retweet handles:  [u'RepJayapal', u'USRepRickNolan', u'RepRaulGrijalva', u'NancyPelosi', u'RepRoKhanna', u'RepAdams', u'RepSwalwell', u'RepPeteAguilar', u'RepCarbajal', u'RepDonBeyer', u'RepRobinKelly', u'RepThompson']
#
#
# Member handle:  RepJohnDelaney
# Member party:  Democratic
# Retweet handles:  [u'GerryConnolly', u'RepJerryNadler', u'RepJuanVargas', u'RosLehtinen']
#
#
# Member handle:  RepJohnDuncanJr
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepJohnFaso
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepJohnKatko
# Member party:  Republican
# Retweet handles:  [u'RepJudyChu', u'SpeakerRyan', u'RepChrisCollins']
#
#
# Member handle:  RepJohnLarson
# Member party:  Democratic
# Retweet handles:  [u'RepJoeKennedy', u'RepRichardNeal', u'RepAnnieKuster']
#
#
# Member handle:  repjohnlewis
# Member party:  Democratic
# Retweet handles:  [u'RepJimmyGomez', u'RepEspaillat', u'RepJayapal', u'RosLehtinen']
#
#
# Member handle:  RepJohnYarmuth
# Member party:  Democratic
# Retweet handles:  [u'RepBeatty', u'RepDebDingell', u'RepSarbanes', u'JacksonLeeTX18', u'RepRaulGrijalva', u'USRepMikeDoyle', u'FrankPallone', u'RepDelBene', u'repjohnlewis', u'RepCheri', u'RepAnnieKuster', u'RepRoKhanna', u'RepJohnYarmuth', u'RepValDemings', u'RepJayapal']
#
#
# Member handle:  RepJoseSerrano
# Member party:  Democratic
# Retweet handles:  [u'RosLehtinen', u'RepCummings']
#
#
# Member handle:  RepJoshG
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepJuanVargas
# Member party:  Democratic
# Retweet handles:  [u'RepJudyChu', u'RepTimWalz', u'RepCummings', u'RepLoisFrankel', u'RepJuanVargas', u'RepTedDeutch']
#
#
# Member handle:  RepJudyChu
# Member party:  Democratic
# Retweet handles:  [u'RepRoybalAllard', u'BillPascrell', u'RepGraceMeng', u'RepJayapal', u'RepAnnieKuster', u'RepBarragan', u'NormaJTorres', u'NancyPelosi', u'TulsiPress', u'janschakowsky']
#
#
# Member handle:  RepKarenBass
# Member party:  Democratic
# Retweet handles:  [u'RepKarenBass', u'RepYvetteClarke', u'RepTerriSewell', u'JacksonLeeTX18', u'RepMiaLove']
#
#
# Member handle:  RepKathleenRice
# Member party:  Democratic
# Retweet handles:  [u'WhipHoyer', u'RepDonBeyer', u'RepValDemings', u'jahimes', u'RepTedLieu', u'repjimcooper', u'repjohnlewis']
#
#
# Member handle:  RepKayGranger
# Member party:  Republican
# Retweet handles:  [u'RepKevinBrady', u'cathymcmorris', u'KenCalvert', u'SteveScalise', u'JudgeCarter', u'RepGallagher', u'CongCulberson', u'RepMarthaRoby', u'HurdOnTheHill', u'SpeakerRyan', u'GOPLeader', u'RepMcSally', u'RepRutherfordFL']
#
#
# Member handle:  RepKClark
# Member party:  Democratic
# Retweet handles:  [u'RepBeatty', u'RepCummings', u'RepJeffries', u'repmarkpocan', u'USRepMikeDoyle', u'RepJerryNadler', u'RepMikeQuigley', u'RepKarenBass', u'RepSarbanes', u'repdinatitus', u'RepTerriSewell']
#
#
# Member handle:  RepKenBuck
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan']
#
#
# Member handle:  RepKenMarchant
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepKevinBrady
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'SteveScalise']
#
#
# Member handle:  RepKevinCramer
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepKevinYoder
# Member party:  Republican
# Retweet handles:  [u'RepSeanDuffy']
#
#
# Member handle:  RepKHandel
# Member party:  Republican
# Retweet handles:  [u'cathymcmorris', u'RepKevinBrady']
#
#
# Member handle:  RepKihuen
# Member party:  Democratic
# Retweet handles:  [u'RepKihuen']
#
#
# Member handle:  RepKinzinger
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepKristiNoem
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepLaHood
# Member party:  Republican
# Retweet handles:  [u'RepDonBacon', u'cathymcmorris']
#
#
# Member handle:  RepLaMalfa
# Member party:  Republican
# Retweet handles:  [u'SteveScalise']
#
#
# Member handle:  RepLanceNJ7
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepLarryBucshon
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'RepKevinBrady']
#
#
# Member handle:  RepLawrence
# Member party:  Democratic
# Retweet handles:  [u'RepRoybalAllard', u'RepGwenMoore', u'RepCummings', u'RepDianaDeGette', u'RepBrady', u'RepJohnYarmuth', u'RepLoisFrankel', u'RepBeatty', u'USRepMikeDoyle', u'RepBarbaraLee', u'USRepKCastor', u'DorisMatsui', u'RepFrenchHill', u'JacksonLeeTX18', u'RepVeasey', u'RepJoeKennedy', u'NancyPelosi', u'repmarkpocan', u'BobbyScott', u'RepKarenBass', u'RepDelBene', u'RepRaskin', u'RepCheri', u'RepStephMurphy']
#
#
# Member handle:  RepLBR
# Member party:  Democratic
# Retweet handles:  [u'RepLoisFrankel', u'NancyPelosi']
#
#
# Member handle:  RepLeeZeldin
# Member party:  Republican
# Retweet handles:  [u'RosLehtinen', u'CongressmanHice', u'SteveScalise']
#
#
# Member handle:  RepLindaSanchez
# Member party:  Democratic
# Retweet handles:  [u'repjohnlewis', u'rosadelauro', u'RepLindaSanchez', u'JacksonLeeTX18', u'RepVeasey', u'BillPascrell', u'RepLoisFrankel', u'RepBonnie', u'repjoecrowley', u'RepThompson', u'repblumenauer', u'RepEspaillat', u'RepRichardNeal', u'RepJohnLarson', u'RepLloydDoggett', u'FrankPallone', u'Clyburn', u'RepLowenthal', u'RepStephMurphy', u'DorisMatsui', u'NancyPelosi', u'RepMikeQuigley', u'RepAdamSchiff', u'DonaldNorcross', u'RepJudyChu', u'WhipHoyer', u'RepAnnieKuster', u'RepBarragan', u'RepTerriSewell', u'RepLouCorrea', u'GerryConnolly', u'RepTedDeutch', u'RepRoKhanna', u'repcleaver', u'RepGaramendi', u'RepRoybalAllard', u'RepJimmyPanetta', u'JuliaBrownley26', u'RepScottPeters', u'RepJohnYarmuth']
#
#
# Member handle:  RepLipinski
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepLizCheney
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepLloydDoggett
# Member party:  Democratic
# Retweet handles:  [u'RepLloydDoggett', u'RepCummings', u'repmarkpocan']
#
#
# Member handle:  RepLoBiondo
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepLoisFrankel
# Member party:  Democratic
# Retweet handles:  [u'RepBeatty', u'RepJeffries', u'RepJoeKennedy', u'RepDebDingell', u'RepBrady', u'RepJohnYarmuth', u'WhipHoyer', u'RepDanDonovan', u'SusanWBrooks', u'NitaLowey', u'USRepMikeDoyle', u'RepKarenBass', u'RepSarbanes', u'chelliepingree', u'RepJayapal', u'RepTerriSewell', u'RepCheri', u'JuliaBrownley26', u'RepMikeQuigley', u'USRepKCastor', u'RepLawrence', u'RepSpeier', u'NancyPelosi', u'RepRaulGrijalva', u'RepGwenMoore', u'RepRichardNeal']
#
#
# Member handle:  RepLouBarletta
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'RepPeteKing']
#
#
# Member handle:  RepLouCorrea
# Member party:  Democratic
# Retweet handles:  [u'RepMikeCapuano', u'USRepKCastor', u'repsandylevin', u'RepAnthonyBrown', u'BillPascrell', u'repjoecrowley', u'RepTimWalz', u'RepSchneider', u'WhipHoyer', u'RepMattGaetz']
#
#
# Member handle:  RepLoudermilk
# Member party:  Republican
# Retweet handles:  [u'RepTomGraves']
#
#
# Member handle:  replouiegohmert
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepLowenthal
# Member party:  Democratic
# Retweet handles:  [u'repjohnlewis', u'RepLowenthal']
#
#
# Member handle:  RepLujanGrisham
# Member party:  Democratic
# Retweet handles:  [u'repmarkpocan', u'RepKarenBass', u'RepJudyChu', u'RepAnnieKuster', u'JacksonLeeTX18', u'RepRaulGrijalva', u'RepVeasey']
#
#
# Member handle:  RepLukeMesser
# Member party:  Republican
# Retweet handles:  [u'RepMarkMeadows']
#
#
# Member handle:  RepLynnJenkins
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepMaloney
# Member party:  Democratic
# Retweet handles:  [u'RepBeatty', u'RepYvetteClarke', u'RepSpeier', u'RepBrady', u'RepKarenBass', u'RepTerriSewell']
#
#
# Member handle:  RepMarciaFudge
# Member party:  Democratic
# Retweet handles:  [u'RepMarcyKaptur', u'RepTimRyan', u'RepPaulTonko', u'RepKarenBass', u'NancyPelosi']
#
#
# Member handle:  RepMarcyKaptur
# Member party:  Democratic
# Retweet handles:  [u'RepTerriSewell', u'RepCummings', u'RepCheri', u'NancyPelosi', u'BobbyScott', u'chelliepingree', u'RepBeatty', u'RepAdamSchiff', u'RepEliotEngel', u'RepDebDingell']
#
#
# Member handle:  RepMarkMeadows
# Member party:  Republican
# Retweet handles:  [u'Jim_Jordan', u'RepGoodlatte', u'RepArrington', u'CongressmanHice', u'JoaquinCastrotx', u'RepLeeZeldin', u'RepAndyBiggsAZ', u'WarrenDavidson', u'RepRodBlum']
#
#
# Member handle:  repmarkpocan
# Member party:  Democratic
# Retweet handles:  [u'RepBeatty', u'RepBarbaraLee', u'RepRoKhanna', u'RepGwenMoore', u'RepMcGovern', u'RepCummings', u'RepJeffries', u'JoaquinCastrotx', u'RepDianaDeGette', u'RepDebDingell', u'chelliepingree', u'RepLloydDoggett', u'RepBrady', u'justinamash', u'janschakowsky', u'RepJohnYarmuth', u'RepHankJohnson', u'USRepMikeDoyle', u'RepJerryNadler', u'CongressmanRuiz', u'RepYvetteClarke', u'RepKarenBass', u'rosadelauro', u'RepSarbanes', u'RepTerriSewell', u'RepAnnieKuster', u'RepJayapal', u'RepRaulGrijalva', u'RepDonBeyer', u'RepRichardNeal', u'RepVeasey']
#
#
# Member handle:  RepMarkTakano
# Member party:  Democratic
# Retweet handles:  [u'RepMarkTakano', u'USRepMikeDoyle', u'RepAnnieKuster', u'FrankPallone', u'RepBillFoster', u'repjohnlewis']
#
#
# Member handle:  RepMarkWalker
# Member party:  Republican
# Retweet handles:  [u'RepMarkWalker']
#
#
# Member handle:  RepMarshall
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepMarthaRoby
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'RepByrne', u'SpeakerRyan']
#
#
# Member handle:  RepMattGaetz
# Member party:  Republican
# Retweet handles:  [u'Jim_Jordan', u'RepThomasMassie']
#
#
# Member handle:  RepMaxineWaters
# Member party:  Democratic
# Retweet handles:  [u'RepMaxineWaters']
#
#
# Member handle:  RepMcCaul
# Member party:  Republican
# Retweet handles:  [u'RepGoodlatte']
#
#
# Member handle:  RepMcClintock
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepMcEachin
# Member party:  Democratic
# Retweet handles:  [u'RepJohnYarmuth', u'RepAnnaEshoo', u'RepHankJohnson', u'WhipHoyer', u'RepRaulGrijalva', u'RepBarbaraLee']
#
#
# Member handle:  RepMcGovern
# Member party:  Democratic
# Retweet handles:  [u'RepBeatty', u'RepGwenMoore', u'BillPascrell', u'RepLloydDoggett', u'chelliepingree', u'RepKClark', u'RosLehtinen', u'RepJayapal', u'WhipHoyer', u'RepMcGovern', u'RepCummings', u'RepBarbaraLee', u'FrankPallone', u'RepAdams']
#
#
# Member handle:  RepMcKinley
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'cathymcmorris', u'RepWebster', u'SpeakerRyan', u'RepBillFlores']
#
#
# Member handle:  RepMcNerney
# Member party:  Democratic
# Retweet handles:  [u'RepVeasey', u'RepTerriSewell', u'RepValDemings', u'RepDonBeyer', u'RepBarbaraLee']
#
#
# Member handle:  RepMcSally
# Member party:  Republican
# Retweet handles:  [u'RepMcSally']
#
#
# Member handle:  RepMGriffith
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepMiaLove
# Member party:  Republican
# Retweet handles:  [u'SteveScalise']
#
#
# Member handle:  RepMikeBishop
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'cathymcmorris', u'RepMikeCoffman', u'RepKevinBrady', u'GOPLeader', u'SpeakerRyan', u'RepHuizenga']
#
#
# Member handle:  RepMikeCapuano
# Member party:  Democratic
# Retweet handles:  [u'RepJayapal']
#
#
# Member handle:  RepMikeCoffman
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan']
#
#
# Member handle:  RepMikeJohnson
# Member party:  Republican
# Retweet handles:  [u'RepWesterman', u'RepAbraham', u'RepCharlieCrist', u'RepLaHood', u'RepTenney', u'RepKevinBrady', u'SteveScalise', u'SpeakerRyan']
#
#
# Member handle:  RepMikeQuigley
# Member party:  Democratic
# Retweet handles:  [u'RepDonBeyer', u'RepMikeQuigley', u'RepTimRyan']
#
#
# Member handle:  RepMikeRogersAL
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepMikeTurner
# Member party:  Republican
# Retweet handles:  [u'TomColeOK04', u'RepLoBiondo', u'nikiinthehouse', u'SpeakerRyan', u'RepDaveJoyce', u'AustinScottGA08', u'JoaquinCastrotx', u'RepEsty', u'RepPaulTonko']
#
#
# Member handle:  RepMimiWalters
# Member party:  Republican
# Retweet handles:  [u'RepMimiWalters']
#
#
# Member handle:  RepMoBrooks
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepMoolenaar
# Member party:  Republican
# Retweet handles:  [u'RepJackBergman', u'RepMikeBishop', u'RepDebDingell', u'RepMarcyKaptur']
#
#
# Member handle:  RepMullin
# Member party:  Republican
# Retweet handles:  [u'RepKClark', u'RepMcSally']
#
#
# Member handle:  RepNewhouse
# Member party:  Republican
# Retweet handles:  [u'RepDerekKilmer', u'RepSeanDuffy', u'cathymcmorris']
#
#
# Member handle:  RepOHalleran
# Member party:  Democratic
# Retweet handles:  [u'RepOHalleran', u'RepSinema']
#
#
# Member handle:  RepPaulCook
# Member party:  Republican
# Retweet handles:  [u'cathymcmorris', u'SpeakerRyan', u'RepEdRoyce', u'GOPLeader']
#
#
# Member handle:  RepPaulMitchell
# Member party:  Republican
# Retweet handles:  [u'RepLukeMesser']
#
#
# Member handle:  RepPaulTonko
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepPerlmutter
# Member party:  Democratic
# Retweet handles:  [u'RepJohnYarmuth', u'RepHankJohnson', u'RepPaulTonko', u'RepJaredPolis', u'RepTerriSewell', u'RepRaulGrijalva', u'RepRichardNeal', u'USRepMikeDoyle', u'RepCummings', u'RepGallagher']
#
#
# ...
#
#
# Member handle:  RepPoliquin
# Member party:  Republican
# Retweet handles:  [u'RepJackyRosen']
#
#
# Member handle:  RepRalphNorman
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepRaskin
# Member party:  Democratic
# Retweet handles:  [u'RepAnthonyBrown', u'RepRoKhanna', u'RepDonBeyer', u'RepBonamici', u'RepLloydDoggett', u'GerryConnolly', u'RepHankJohnson', u'RepJudyChu', u'RepGraceMeng', u'RepValDemings', u'NancyPelosi', u'RepMcGovern', u'WhipHoyer', u'RepBarragan', u'RepYvetteClarke', u'RepPaulTonko', u'RepDennyHeck', u'RepAdams', u'RepTimRyan', u'RepLindaSanchez', u'RepBonnie', u'RepJerryNadler', u'RepJayapal']
#
#
# Member handle:  RepRatcliffe
# Member party:  Republican
# Retweet handles:  [u'RepRoKhanna', u'JimLangevin', u'RepWesterman', u'RepMarkWalker']
#
#
# Member handle:  RepRaulGrijalva
# Member party:  Democratic
# Retweet handles:  [u'repmarkpocan']
#
#
# Member handle:  RepRichardNeal
# Member party:  Democratic
# Retweet handles:  [u'FrankPallone', u'RepMcGovern']
#
#
# Member handle:  RepRichHudson
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepRichmond
# Member party:  Democratic
# Retweet handles:  [u'repjohnlewis', u'RepYvetteClarke', u'RepTerriSewell', u'RepDanKildee', u'WhipHoyer', u'RepJohnYarmuth']
#
#
# Member handle:  RepRickAllen
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan']
#
#
# Member handle:  RepRickCrawford
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepRickLarsen
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepRobBishop
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepRobinKelly
# Member party:  Democratic
# Retweet handles:  [u'RepBeatty', u'repjohnlewis', u'RepJeffries', u'RepTerriSewell', u'JacksonLeeTX18', u'janschakowsky', u'WhipHoyer', u'FrankPallone']
#
#
# Member handle:  RepRobWoodall
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan']
#
#
# Member handle:  RepRodBlum
# Member party:  Republican
# Retweet handles:  [u'Jim_Jordan']
#
#
# Member handle:  RepRohrabacher
# Member party:  Republican
# Retweet handles:  [u'RepThomasMassie', u'RepLowenthal']
#
#
# Member handle:  RepRoKhanna
# Member party:  Democratic
# Retweet handles:  [u'RepBarbaraLee', u'repmarkpocan', u'RepJayapal', u'RepLloydDoggett', u'NancyPelosi', u'rosadelauro', u'RepRoKhanna', u'RepJoeKennedy', u'RepRatcliffe', u'RepDebDingell', u'WhipHoyer', u'RepAdamSmith']
#
#
# Member handle:  RepRonEstes
# Member party:  Republican
# Retweet handles:  [u'cathymcmorris', u'RepKevinBrady', u'SpeakerRyan']
#
#
# Member handle:  RepRonKind
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepRooney
# Member party:  Republican
# Retweet handles:  [u'RepTedBudd', u'RepLeeZeldin', u'RepDianeBlack', u'SteveScalise', u'SpeakerRyan', u'RepJoeWilson', u'RosLehtinen']
#
#
# Member handle:  RepRoybalAllard
# Member party:  Democratic
# Retweet handles:  [u'RosLehtinen']
#
#
# Member handle:  RepRubenGallego
# Member party:  Democratic
# Retweet handles:  [u'RepSpeier', u'RepRaskin', u'JacksonLeeTX18', u'RepRaulGrijalva', u'JoaquinCastrotx', u'RepSwalwell', u'RepVeasey', u'RepDonBeyer']
#
#
# Member handle:  RepRussell
# Member party:  Republican
# Retweet handles:  [u'RepAbraham']
#
#
# Member handle:  RepRutherfordFL
# Member party:  Republican
# Retweet handles:  [u'cathymcmorris']
#
#
# Member handle:  RepRWilliams
# Member party:  Republican
# Retweet handles:  [u'SteveScalise']
#
#
# Member handle:  RepRyanCostello
# Member party:  Republican
# Retweet handles:  [u'daveloebsack', u'RepAndreCarson', u'RepStephMurphy', u'RepBarragan', u'RepTomEmmer', u'RepSpeier']
#
#
# Member handle:  RepSamGraves
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'RepSmucker']
#
#
# Member handle:  repsandylevin
# Member party:  Democratic
# Retweet handles:  [u'repjohnlewis', u'WhipHoyer', u'RepCummings', u'RepDaveJoyce', u'RepJohnYarmuth']
#
#
# Member handle:  RepSanfordSC
# Member party:  Republican
# Retweet handles:  [u'RepLanceNJ7', u'Clyburn']
#
#
# Member handle:  RepSarbanes
# Member party:  Democratic
# Retweet handles:  [u'NancyPelosi', u'RepTerriSewell', u'repmarkpocan', u'WhipHoyer', u'GerryConnolly', u'repjohnlewis', u'RepCheri', u'RepAdamSchiff', u'RepJerryNadler', u'RepJayapal']
#
#
# Member handle:  RepSchneider
# Member party:  Democratic
# Retweet handles:  [u'RepSchneider', u'RepTedDeutch', u'RepBobbyRush', u'RepDelBene', u'RosLehtinen']
#
#
# Member handle:  RepSchrader
# Member party:  Democratic
# Retweet handles:  [u'RepOHalleran']
#
#
# Member handle:  RepScottPerry
# Member party:  Republican
# Retweet handles:  [u'RepMarkMeadows', u'RepLeeZeldin', u'justinamash', u'Jim_Jordan']
#
#
# Member handle:  RepScottPeters
# Member party:  Democratic
# Retweet handles:  [u'RepAdamSchiff']
#
#
# Member handle:  RepScottTaylor
# Member party:  Republican
# Retweet handles:  [u'RepTedLieu', u'SpeakerRyan', u'BobbyScott', u'GOPLeader']
#
#
# Member handle:  RepSeanDuffy
# Member party:  Republican
# Retweet handles:  [u'RepTomGraves', u'RepDougCollins', u'RepSeanDuffy', u'repgregwalden', u'RepRichHudson', u'RepSteveStivers', u'cathymcmorris', u'SteveScalise', u'RepGallagher', u'RepJasonSmith', u'SpeakerRyan']
#
#
# Member handle:  RepSeanMaloney
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepSheaPorter
# Member party:  Democratic
# Retweet handles:  [u'RepSheaPorter', u'BobbyScott']
#
#
# Member handle:  RepShimkus
# Member party:  Republican
# Retweet handles:  [u'boblatta', u'GOPLeader', u'cathymcmorris', u'RepPeteOlson', u'RepKinzinger', u'RepLouBarletta', u'repgregwalden', u'RodneyDavis', u'RepJimBanks', u'RepKevinBrady', u'SteveScalise', u'RepWalberg', u'RepMimiWalters', u'SpeakerRyan']
#
#
# Member handle:  RepSinema
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepSires
# Member party:  Democratic
# Retweet handles:  [u'BillPascrell', u'FrankPallone', u'RepJerryNadler']
#
#
# Member handle:  RepSmucker
# Member party:  Republican
# Retweet handles:  [u'RepSmucker', u'SpeakerRyan', u'cathymcmorris', u'SteveScalise', u'RepLouBarletta', u'RepCarbajal', u'CongressmanGT', u'GOPLeader']
#
#
# Member handle:  RepSpeier
# Member party:  Democratic
# Retweet handles:  [u'RepLoisFrankel']
#
#
# Member handle:  RepStefanik
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'RepStefanik']
#
#
# Member handle:  RepStephenLynch
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepStephMurphy
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepSteveChabot
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'RepSteveChabot', u'USRepRickNolan', u'RepGoodlatte', u'RepLowenthal', u'virginiafoxx', u'repjoecrowley']
#
#
# Member handle:  RepStevePearce
# Member party:  Republican
# Retweet handles:  [u'SteveScalise']
#
#
# Member handle:  RepSteveStivers
# Member party:  Republican
# Retweet handles:  [u'SteveScalise']
#
#
# Member handle:  RepSusanDavis
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepSwalwell
# Member party:  Democratic
# Retweet handles:  [u'RepSteveStivers', u'RepSwalwell']
#
#
# Member handle:  RepTedBudd
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'RepAdams']
#
#
# Member handle:  RepTedDeutch
# Member party:  Democratic
# Retweet handles:  [u'RepTedDeutch', u'repjohnlewis', u'RepJohnYarmuth', u'RepAdamSchiff', u'RepJoeKennedy', u'RepCummings', u'RepLloydDoggett', u'WhipHoyer', u'FrankPallone']
#
#
# Member handle:  RepTedLieu
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepTedYoho
# Member party:  Republican
# Retweet handles:  [u'RepTedLieu', u'SteveScalise']
#
#
# Member handle:  RepTenney
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'RepKinzinger', u'RosLehtinen']
#
#
# Member handle:  RepTerriSewell
# Member party:  Democratic
# Retweet handles:  [u'RepSarbanes', u'RepTerriSewell', u'GKButterfield', u'RepVeasey', u'RepRoybalAllard']
#
#
# Member handle:  RepThomasMassie
# Member party:  Republican
# Retweet handles:  [u'justinamash', u'Jim_Jordan', u'RepMarkMeadows']
#
#
# Member handle:  RepThompson
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepTimRyan
# Member party:  Democratic
# Retweet handles:  [u'RepBarbaraLee', u'RepMarcyKaptur']
#
#
# Member handle:  RepTimWalz
# Member party:  Democratic
# Retweet handles:  [u'RepTimWalz', u'RepDelBene', u'RepScottPeters']
#
#
# Member handle:  RepTipton
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'RepTomGraves', u'cathymcmorris']
#
#
# Member handle:  RepTomEmmer
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'PatrickMcHenry']
#
#
# Member handle:  RepTomGarrett
# Member party:  Republican
# Retweet handles:  [u'RepMattGaetz', u'RepMarkMeadows']
#
#
# Member handle:  RepTomGraves
# Member party:  Republican
# Retweet handles:  [u'GOPLeader', u'RepJimBanks', u'SteveScalise', u'SpeakerRyan']
#
#
# Member handle:  RepTomMacArthur
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'RepAnnieKuster']
#
#
# Member handle:  RepTomMarino
# Member party:  Republican
# Retweet handles:  [u'RepTomMarino', u'davidcicilline']
#
#
# Member handle:  RepTomReed
# Member party:  Republican
# Retweet handles:  [u'RepDianaDeGette', u'RepTomReed', u'RepEliotEngel', u'RepGaramendi']
#
#
# Member handle:  RepTomRice
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan']
#
#
# Member handle:  RepTomSuozzi
# Member party:  Democratic
# Retweet handles:  [u'RepJimmyPanetta']
#
#
# Member handle:  RepTrentKelly
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  RepTrey
# Member party:  Republican
# Retweet handles:  [u'RepJoshG']
#
#
# Member handle:  RepValDemings
# Member party:  Democratic
# Retweet handles:  [u'repjohnlewis', u'RepValDemings', u'RepRaskin', u'janschakowsky', u'RepJayapal', u'RepGwenMoore', u'RepMaloney']
#
#
# Member handle:  RepVeasey
# Member party:  Democratic
# Retweet handles:  [u'RosLehtinen', u'RepVeasey', u'repmarkpocan', u'JacksonLeeTX18', u'RepAdamSmith', u'RepGeneGreen', u'RepRaulGrijalva', u'RepBeatty', u'RepBobbyRush', u'RepWilson', u'RepTimRyan', u'RepMarkTakano', u'RepDerekKilmer', u'RepPerlmutter', u'RepBarragan', u'RepLawrence', u'RepMarcyKaptur', u'RepDebDingell', u'RepBonamici', u'RepTerriSewell', u'RepSarbanes', u'RepGregoryMeeks']
#
#
# Member handle:  RepVisclosky
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  RepWalberg
# Member party:  Republican
# Retweet handles:  [u'RepTimRyan', u'RepFredUpton', u'RepDebDingell']
#
#
# Member handle:  RepWalorski
# Member party:  Republican
# Retweet handles:  [u'CongressmanRuiz']
#
#
# Member handle:  RepWebster
# Member party:  Republican
# Retweet handles:  [u'RepJimRenacci', u'RepLipinski', u'JudgeTedPoe', u'SteveKingIA']
#
#
# Member handle:  RepWesterman
# Member party:  Republican
# Retweet handles:  [u'SteveScalise']
#
#
# Member handle:  RepWilson
# Member party:  Democratic
# Retweet handles:  [u'NancyPelosi', u'RepCummings', u'RepJeffries', u'RepJohnYarmuth', u'repmarkpocan', u'RepTerriSewell', u'JacksonLeeTX18', u'RepRaulGrijalva', u'RepGwenMoore', u'RepWilson']
#
#
# Member handle:  RepYvetteClarke
# Member party:  Democratic
# Retweet handles:  [u'NancyPelosi', u'RepCummings']
#
#
# Member handle:  RepZoeLofgren
# Member party:  Democratic
# Retweet handles:  [u'RepJeffries', u'WhipHoyer', u'FrankPallone', u'RepDeSaulnier', u'RepMikeQuigley', u'RepAdamSchiff', u'RepDebDingell', u'RepJerryNadler', u'NancyPelosi', u'RepAnnieKuster', u'RepTedLieu', u'RepJuanVargas', u'RepCummings', u'RepValDemings', u'RepHuffman', u'RepBillFoster', u'USRepKCastor', u'RepEsty', u'RepMarkTakano', u'RepSarbanes', u'RepTedDeutch', u'BennieGThompson', u'RepRobinKelly', u'RepSpeier', u'RepMcGovern', u'rosadelauro', u'RepRoybalAllard', u'JimPressOffice', u'RepJudyChu', u'repmarkpocan', u'repjoecrowley', u'BillPascrell', u'RepMaxineWaters', u'RepJohnLarson']
#
#
# Member handle:  Rep_Hunter
# Member party:  Republican
# Retweet handles:  [u'RepDianeBlack']
#
#
# Member handle:  rep_stevewomack
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan']
#
#
# Member handle:  Robert_Aderholt
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan']
#
#
# Member handle:  RobWittman
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'cathymcmorris', u'RepGallagher']
#
#
# Member handle:  RodneyDavis
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'RepKinzinger', u'RepLaHood']
#
#
# Member handle:  rosadelauro
# Member party:  Democratic
# Retweet handles:  [u'RepJohnLarson', u'janschakowsky', u'repmarkpocan', u'RepRoybalAllard', u'RepLawrence', u'RepAnnieKuster', u'RepLloydDoggett', u'RepBarragan', u'RepDelBene']
#
#
# Member handle:  RosLehtinen
# Member party:  Republican
# Retweet handles:  [u'RepCurbelo']
#
#
# Member handle:  RothfusForPA
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  SamsPressShop
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'RepPeteOlson']
#
#
# Member handle:  SanfordBishop
# Member party:  Democratic
# Retweet handles:  [u'RepLouCorrea', u'RepJohnLarson', u'rep_stevewomack']
#
#
# Member handle:  sethmoulton
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  SpeakerRyan
# Member party:  Republican
# Retweet handles:  [u'RepMikeBishop', u'repgregwalden', u'boblatta', u'PatrickMcHenry', u'davereichert', u'RepMikeCoffman', u'RepTomGraves']
#
#
# Member handle:  SteveKingIA
# Member party:  Republican
# Retweet handles:  [u'SteveKingIA', u'RepGosar']
#
#
# Member handle:  SteveKnight25
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan']
#
#
# Member handle:  SteveScalise
# Member party:  Republican
# Retweet handles:  [u'repgregwalden', u'DrNealDunnFL2', u'MarshaBlackburn', u'cathymcmorris']
#
#
# Member handle:  SusanWBrooks
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'repgregwalden', u'SteveScalise']
#
#
# Member handle:  TGowdySC
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan', u'RepRatcliffe']
#
#
# Member handle:  ToddRokita
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  TomColeOK04
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  TomRooney
# Member party:  Republican
# Retweet handles:  [u'RepTerriSewell', u'RosLehtinen', u'RepTedDeutch', u'TomRooney', u'RepKinzinger', u'RepThompson', u'RepAndyBarr']
#
#
# Member handle:  TulsiPress
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  TXRandy14
# Member party:  Republican
# Retweet handles:  [u'RepHensarling', u'SteveScalise']
#
#
# Member handle:  USRepGaryPalmer
# Member party:  Republican
# Retweet handles:  []
#
#
# Member handle:  USRepKCastor
# Member party:  Democratic
# Retweet handles:  [u'RepJoeKennedy', u'RepJeffries', u'repjohnlewis', u'RepDebDingell', u'RepCharlieCrist', u'RepJohnYarmuth', u'repmarkpocan', u'RepTerriSewell', u'RepAnnieKuster', u'JacksonLeeTX18', u'RepRaulGrijalva', u'RepRichardNeal', u'USRepMikeDoyle', u'RepCummings', u'RepDelBene', u'davidcicilline']
#
#
# Member handle:  USRepKeating
# Member party:  Democratic
# Retweet handles:  []
#
#
# Member handle:  USRepLong
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan']
#
#
# Member handle:  USRepMikeDoyle
# Member party:  Democratic
# Retweet handles:  [u'RepBeatty', u'RepJeffries', u'RepJohnYarmuth', u'RepHankJohnson', u'RepDelBene', u'RepStephMurphy', u'RepDennyHeck', u'FrankPallone']
#
#
# Member handle:  USRepRickNolan
# Member party:  Democratic
# Retweet handles:  [u'RepJohnYarmuth', u'RepGallagher']
#
#
# Member handle:  USRepRodney
# Member party:  Republican
# Retweet handles:  [u'SpeakerRyan']
#
#
# Member handle:  VernBuchanan
# Member party:  Republican
# Retweet handles:  [u'RosLehtinen']
#
#
# Member handle:  virginiafoxx
# Member party:  Republican
# Retweet handles:  [u'SteveScalise', u'SpeakerRyan', u'cathymcmorris']
#
#
# Member handle:  WarrenDavidson
# Member party:  Republican
# Retweet handles:  [u'justinamash', u'WarrenDavidson', u'RepMarkMeadows', u'Jim_Jordan', u'SteveScalise']
#
#
# Member handle:  WhipHoyer
# Member party:  Democratic
# Retweet handles:  [u'RepBeatty', u'RepGwenMoore', u'RepCummings', u'JoaquinCastrotx', u'RepDianaDeGette', u'RepBrady', u'repmarkpocan', u'RepHankJohnson', u'USRepMikeDoyle', u'RepAdams', u'RepJerryNadler', u'CongressmanRuiz', u'RepKarenBass', u'RepSarbanes', u'RepTerriSewell', u'RepAnnieKuster', u'JacksonLeeTX18', u'repjohnlewis', u'RepVeasey', u'RepLawrence', u'RepLoisFrankel', u'RepRaulGrijalva']

# %% [markdown]
#  _Exercise_ 2: Visualize the network of retweets and investigate differences between the parties.
#  * Visualize the network using the [Networkx draw function](https://networkx.github.io/documentation/stable/reference/generated/networkx.drawing.nx_pylab.draw.html#networkx.drawing.nx_pylab.draw), and nodes coordinates from the force atlas algorithm (see Week 5, Exercise 2). _Hint: use the undirected version of the graph to find the nodes positions for better results, but stick to the directed version for all measurements._ Plot nodes in colors according to their party (e.g. 'red' for republicans and 'blue' for democrats) and set the nodes' size proportional to their total degree.
#   * Compare the network of Retweets with the network of Wikipedia pages (Week 5, exercise 2). Do you observe any difference? How do you explain them?
# * Now set the nodes' size proportional to their betweenness centrality. What do you observe?
# * Repeat the point above using eigenvector centrality instead. Is there any difference? Can you explain why?
# * Who are the three nodes with highest degree within each party? And eigenvector centrality? And betweenness centrality?
# * Plot on the same figure the distribution of outgoing strength for the republican and democratic nodes (e.g. the sum of the weight on outgoing links). Which party is more active in retweeting other members of the house?
# * Find the 3 members of the republican party that have retweet more often tweets from democratic members. Repeat the measure for the democratic members. Can you explain your results by looking at the Wikipedia pages of these members of the house?

# %% [markdown]
# _Exercise_ 3: Community detection.
#
# * Use your favorite method of community detection to find communities in the full house of representatives network. Report the value of modularity found by the algorithm. Is it higher or lower than what you found for the Wikipedia network? Comment on your result.
# * Visualize the network, using the Force Atlas algorithm (see Lecture 5, exercise 2). This time assign each node a different color based on their _community_. Describe the structure you observe.
# * Compare the communities found by your algorithm with the parties by creating a matrix $\mathbf{D}$ with dimension $(B \times C$, where $B$ is the number of parties and $C$ is the number of communities. We set entry $D(i,j)$ to be the number of nodes that party $i$ has in common with community $j$. The matrix $\mathbf{D}$ is what we call a [**confusion matrix**](https://en.wikipedia.org/wiki/Confusion_matrix).
# *  [Plot the confusion matrix](https://scipython.com/book/chapter-7-matplotlib/examples/visualizing-a-matrix-with-imshow/) and explain how well the communities you've detected correspond to the parties. Consider the following questions:
#   * Are there any republicans grouped with democrats (and vice versa)?
#   * Does the community detection algorithm sub-divide the parties? Do you know anything about American politics that could explain such sub-divisions? Answer in your own words.

# %% [markdown]
# # Part 2: What do republican and democratic members tweet about?

# %% [markdown]
# _Exercise_ 4: TF-IDF of the republican and democratic tweets.
#
# We will create two documents, one containing the words extracted from tweets of republican members, and the other for Democratic members. We will then use TF-IDF to compare the content of these two documents and create a word-cloud. The procedure you should use is exactly the same you used in exercise 2 of week 7. The main steps are summarized below:
# * Create two large documents, one for the democratic and one for the republican party. Tokenize the pages, and combine the tokens into one long list including all the pages of the members of the same party.
#   * Exclude all twitter handles.
#   * Exclude punctuation.
#   * Exclude stop words (if you don't know what stop words are, go back and read NLPP1e again).
#   * Exclude numbers (since they're difficult to interpret in the word cloud).
#   * Set everything to lower case.
#   * Compute the TF-IDF for each document.
# * Now, create word-cloud for each party. Are these topics less "boring" than the wikipedia topics from a few weeks ago? Why?  Comment on the results.

# %%
import nltk

dem_tokens = [];
dem_tweets = "";
rep_tokens = [];
rep_tweets = "";

# find all files in folder
for filename in os.listdir("tweets/"):    
    # open file
    filepath = "tweets/" + filename
    file = io.open(filepath, 'r', encoding='utf-8');
    
    tweets = "";
    # search for retweet
    for line in file: 
        tweets = tweets + line;
    
    # find member party
    for index, member in enumerate(party_handles, start=0):
        if filename == party_handles[index]:
            if parties[index] == "Democratic":
                dem_tokens += nltk.word_tokenize(tweets);
                dem_tweets += tweets;
            else:
                rep_tokens += nltk.word_tokenize(tweets);
                rep_tweets += tweets;
            break;

# %%
# Exclude twitter handles.
dem_handles = []
for i, e in enumerate(dem_tokens): 
    if e == "@":
        dem_handles.append(dem_tokens[i+1]);

for handle in dem_handles:
    dem_tokens.remove(handle);
        
rep_handles = []
for i, e in enumerate(rep_tokens): 
    if e == "@":
        rep_handles.append(rep_tokens[i+1]);
        
for handle in rep_handles:
    rep_tokens.remove(handle);

# %%
#remove punctuation and lowercase
dem_tokens = [word.lower() for word in dem_tokens if word.isalpha()]
rep_tokens = [word.lower() for word in rep_tokens if word.isalpha()]

# %%
#remove stopwords
nltk.download('stopwords');
from nltk.corpus import stopwords #remove of stopwords

stop = set(stopwords.words('english'))
dem_tokens = [word for word in dem_tokens if word not in stopwords.words('english')]
rep_tokens = [word for word in rep_tokens if word not in stopwords.words('english')]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fpegios\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# exclude numbers
dem_tokens = [item for item in dem_tokens if not item.isdigit()]
rep_tokens = [item for item in rep_tokens if not item.isdigit()]

# %%
# print tokens to text files
dem_tweets_file = open('dem_tweets.txt','w');
for word in dem_tokens:
    word_w = word.encode("UTF-8") + "\n";
    dem_tweets_file.write(word_w);

rep_tweets_file = open('rep_tweets.txt','w');
for word in rep_tokens:
    word_w = word.encode("UTF-8") + "\n";
    rep_tweets_file.write(word_w);

# %%
# calculate the TF
def freq(word, doc):
    return "".join(text).count(word)


def word_count(doc):
    return len(doc)


def tf(word, doc):
    return (freq(word, doc) / float(word_count(doc)))

dem_tfList = []
for i in range(len(dem_tokens)):
    dem_tfList.append(tf(dem_tokens[i], dem_tweets))

rep_tfList = []
for i in range(len(rep_tokens)):
    rep_tfList.append(tf(rep_tokens[i], rep_tweets))
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-8-e2ce9c95d94a> in <module>()
#      13 tfList = []
#      14 for i in range(len(rep_tokens)):
# ---> 15     tfList.append(tf(rep_tokens[i],text))
#
# NameError: name 'text' is not defined

# %%
# calculate the IDF
def idf(self, term):
    """ The number of texts in the corpus divided by the
    number of texts that the term appears in.
    If a term does not appear in the corpus, 0.0 is returned. """
    # idf values are cached for performance.
    idf = self._idf_cache.get(term)
    if idf is None:
        matches = len([True for text in self._texts if term in text])
        # FIXME Should this raise some kind of error instead?
        idf = (log(len(self._texts) / matches) if matches else 0.0)
        self._idf_cache[term] = idf
    return idf
    
def tf_idf(self, term, text):
    return self.tf(term, text) * self.idf(term)
    
dem_tf_idf("", dem_tokens[1], dem_tweets)
rep_tf_idf("", rep_tokens[1], rep_tweets)

# %% [markdown]
# # Part 3: Sentiment analysis

# %%
import nltk
nltk.download('gutenberg')
nltk.download('genesis')
nltk.download('inaugural')
nltk.download('nps_chat')
nltk.download('webtext')
nltk.download('treebank')

from nltk.book import * # importing texts

from nltk.corpus import * # importing nltk
from string import punctuation
import nltk
stopwords = nltk.corpus.stopwords.words('english')

from itertools import izip 
import matplotlib.pyplot as plt # plot
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\fpegios\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package genesis to
# [nltk_data]     C:\Users\fpegios\AppData\Roaming\nltk_data...
# [nltk_data]   Package genesis is already up-to-date!
# [nltk_data] Downloading package inaugural to
# [nltk_data]     C:\Users\fpegios\AppData\Roaming\nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!
# [nltk_data] Downloading package nps_chat to
# [nltk_data]     C:\Users\fpegios\AppData\Roaming\nltk_data...
# [nltk_data]   Package nps_chat is already up-to-date!
# [nltk_data] Downloading package webtext to
# [nltk_data]     C:\Users\fpegios\AppData\Roaming\nltk_data...
# [nltk_data]   Package webtext is already up-to-date!
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\fpegios\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\treebank.zip.
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# _Exercise_ 5: Sentiment over the Twitter data.
#
# * Download the LabMT wordlist. It's available as supplementary material from [Temporal Patterns of Happiness and Information in a Global Social Network: Hedonometrics and Twitter](http://journals.plos.org/plosone/article?id=10.1371/journal.pone.0026752) (Data Set S1). Describe briefly how the list was generated.

# %% [markdown]
# The data were collected from users from Mechanical Turk. This wordlist has a set of 10222 words and their average happiness evaluations according to Mechanical Turk users. Words are ordered according to average happiness which is calculated by various source: (1) word, (2) rank, (3) average happiness (50 user evalutions), (4) standard deviation of happiness, (5) Twitter rank, (6) Google Books rank, (7) New York Times rank, (8) Music Lyrics rank.

# %%
def dictionary(fileName):
    rows = {}
    columns = {};
    for num, line in enumerate(fileName): # reading the file
        
        if num == 0: # Get the headers line
            headings = line.split("\t") ## split it with the char "\t"
            k = 0
            for heading in headings:
                heading = heading.strip() # remove unwanted characters like \n
                rows[heading] = []
                columns[k] = heading
                k += 1
                
        else:
            cells = line.split("\t") # split it with the char "\t"
            k = 0
            for cell in cells:
                cell = cell.strip() # remove unwanted characters like \n
                rows[columns[k]] += [cell]
                k += 1
                
    return rows, columns

with open(dataset.txt) as f:
    f = file(os.getcwd()+ '/dataset.txt', 'r')
rows, columns = dictionary(f) # should create a dictionary for easy reading of the wordlist
f.close()
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-20-8e8ffe7600c1> in <module>()
#      23     return rows, columns
#      24
# ---> 25 f = file(os.getcwd()+ '/dataset.txt', 'r')
#      26 rows, columns = dictionary(f) # should create a dictionary for easy reading of the wordlist
#      27 f.close()
#
# TypeError: '_io.TextIOWrapper' object is not callable

# %% [markdown]
# * Based on the LabMT word list, write a function that calculates sentiment given a list of tokens (the tokens should be lower case, etc).

# %% [markdown]
# * Create two lists: one including the tweets written by democratic members, and the other including the tweets written by republican members (in the text files, tweets are separated by newlines).

# %% [markdown]
# * Calculate the sentiment of each tweet and plot the distribution of sentiment for each of the two lists. Are there significant differences between the two? Which party post more positive tweets?

# %% [markdown]
# * Compute the average _m_ and standard deviation $\sigma$  of the tweets sentiment (considering tweets by both republican and democrats).

# %% [markdown]
# * Now consider only tweets with sentiment lower than m-2$\sigma$. We will refer to them as _negative_ tweets.  Build a list containing the _negative_ tweets written by democrats, and one for republicans. Compute the TF-IDF for these two lists (use the same pre-processing steps in Exercise 5). Create a word-cloud for each of them. Comment on the differences between the _negative_ contents posted by republicans and democrats.

# %% [markdown]
# * Repeat the point above, but considering _positive_ tweets instead (e.g. with sentiment larger than m+2$\sigma$). Comment on your results.
